# %% [markdown]
# # Ejercicio 1
#
# El programa del notebook 3.2 que calculaba las palabras más utilizadas se puede reescribir de forma mucho más sencilla utilizando un `pandas` o `numpy`.
#
# Para ello, en lugar de devolver un diccionario en la función `words_to_frequencies` se puede devolver una `Series` de Pandas.

# %% [markdown]
# Resultado del ejercicio 3.2:
#
# ```console
# Palabras más frecuentes con más de 10 apariciones.
# [('que', 19), ('tu', 17), ('a', 15)]
#
#
# Palabras más frecuentes con más de 5 apariciones.
# [('que', 19), ('un', 5), ('tu', 17), ('el', 6), ('de', 9), ('te', 8), ('a', 15), ('mi', 6), ('favoritos', 9), ('tus', 5)]
# ```

# %%
with open('despacito.txt', 'r', encoding='utf-8') as file:
    lyrics = file.read()
