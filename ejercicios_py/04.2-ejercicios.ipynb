# %% [markdown]
# # Ejercicio 1
#
# * Teneís las siguientes funciones

# %%
def print_add(x, y):
    print(x + y)

def print_sub(x, y):
    print(x - y)

def print_message(msg):
    print(msg)

# %% [markdown]
# Vamos a crear un paquete.
#
# Moved las funciones de arriba y cread el sistema de ficheros/carpetas tal que los siguientes comandos funcionen correctamente.

# %%
# Vamos a crear un paquete con nombre demo_master
x = 5
y = 3
msg = "Hola"

if __name__ == "__main__":
    print_add(x, y)
    print_sub(x, y)
    print_message(msg)
# Out:
# 8
# 2
# Hola

# %%
import demo_master

demo_master.print_sub(1, 2)
demo_master.test1.print_add(1, 2)
demo_master.test2.functions.print_message('hello')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import demo_master
#       3 demo_master.print_sub(1, 2)
#       4 demo_master.test1.print_add(1, 2)
#
# ModuleNotFoundError: No module named 'demo_master'
